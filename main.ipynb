# %% [markdown]
# ## ИМПОРТЫ БИБЛИОТЕК И ЗАГРУЗКА ФАЙЛА

# %%
import pandas as pd 
import sys
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('')

# %% [markdown]
# ## ОЧИСТКА ДАННЫХ (УДАЛЕНИЕ ПУСТЫХ СТРОК, УДАЛЕНИЕ ДУБЛИКАТОВ)
